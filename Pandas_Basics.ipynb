# %%
import os
os.listdir()
# Out:
# ['.DS_Store',
#  'englishThesauras.py',
#  'Untitled.ipynb',
#  'englishThesauras_database.py',
#  '__pycache__',
#  'data.json',
#  'supermarkets',
#  '.ipynb_checkpoints',
#  '.git']

# %%
import pandas

# %%
df1 = pandas.read_csv("supermarkets/supermarkets.csv")
df2 = pandas.read_json("supermarkets/supermarkets.json")
# df3 = pandas.read_excel("supermarkets/supermarkets.xls",sheet_name=0)
df4 = pandas.read_csv("supermarkets/supermarkets-semi-colons.txt",sep = ";")

# %% [markdown]
# df4

# %%
df4
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df1["Address"] += df1["City"]+","+df1["State"]+","+df1["Country"]

# %%
from geopy.geocoders import ArcGIS

# %%
cord = ArcGIS()

# %%
df1["Co-ords"] = df1["Address"].apply(cord.geocode)

# %%
df1["Lat"]  = df1["Co-ords"].apply(lambda x: x.latitude if x!=None else None)
df1["Long"] = df1["Co-ords"].apply(lambda x: x.longitude if x!=None else None)

# %% [markdown]
# #

# %%
df1["Address"] = df1["Co-ords"].apply(lambda x:x.address if x!=None else None)

# %%
df1.drop("Co-ords",axis=1)
# Out:
#    ID                                            Address           City  \
# 0   1     3666 21st St, San Francisco, California, 94114  San Francisco
# 1   2   735 Dolores St, San Francisco, California, 94110  San Francisco
# 2   3      332 Hill St, San Francisco, California, 94114  San Francisco
# 3   4     3995 23rd St, San Francisco, California, 94114  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, 94114  San Francisco
# 5   6  551 Alvarado St, San Francisco, California, 94114  San Francisco
#
#               State Country         Name  Employees        Lat        Long
# 0          CA 94114     USA      Madeira          8  37.756648 -122.429375
# 1          CA 94119     USA  Bready Shop         15  37.757819 -122.425337
# 2  California 94114     USA  Super River         25  37.755875 -122.428816
# 3          CA 94114     USA   Ben's Shop         10  37.752922 -122.431697
# 4        California     USA      Sanchez         12  37.752131 -122.430028
# ...
